# %%
import pandas as pd

# %%
df = pd.read_csv('CSV/Consumer_Complaints.csv', low_memory=False)

# %%
df.describe()
# Out:
#        Complaint ID
# count  6.291060e+05
# mean   1.079504e+06
# std    6.128717e+05
# min    1.000000e+00
# 25%    5.554702e+05
# 50%    1.102279e+06
# 75%    1.612109e+06
# max    2.108121e+06

# %%
df.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0     7/29/2013            Consumer Loan                 Vehicle loan
# 1     7/29/2013  Bank account or service             Checking account
# 2     7/29/2013  Bank account or service             Checking account
# 3     7/29/2013  Bank account or service             Checking account
# 4     7/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %%
df.tail()
# Out:
#        Date received           Product     Sub-product  \
# 629101     8/18/2016          Mortgage  Other mortgage
# 629102     8/11/2016   Debt collection     Payday loan
# 629103     7/14/2016  Credit reporting             NaN
# 629104     8/30/2016  Credit reporting             NaN
# 629105     8/25/2016   Debt collection     Credit card
#
#                                            Issue  \
# 629101  Loan modification,collection,foreclosure
# 629102     Cont'd attempts collect debt not owed
# 629103    Incorrect information on credit report
# 629104    Incorrect information on credit report
# 629105           Disclosure verification of debt
#
#                                    Sub-issue  \
# 629101                                   NaN
# 629102                      Debt is not mine
# 629103                  Personal information
# 629104                  Personal information
# 629105  Not given enough info to verify debt
#
# ...

# %%
df.dropna()
# Out:
#        Date received          Product                            Sub-product  \
# 58174      3/24/2015      Payday loan                            Payday loan
# 58332      3/19/2015  Debt collection                                Medical
# 58389      3/24/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 58470      3/19/2015  Debt collection                          I do not know
# 58483      3/19/2015  Debt collection                          I do not know
# 58503      3/19/2015  Debt collection                          I do not know
# 58606      3/24/2015  Debt collection                                Medical
# 59090      3/25/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 59184       4/3/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 59195       4/3/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 59617       4/9/2015  Debt collection                          I do not know
# ...

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df['Issue'].unique()
# Out:
# array(['Managing the loan or lease', 'Using a debit or ATM card',
#        'Account opening, closing, or management',
#        'Deposits and withdrawals',
#        'Loan servicing, payments, escrow account',
#        "Cont'd attempts collect debt not owed", 'Billing statement',
#        'Loan modification,collection,foreclosure', 'Communication tactics',
#        'APR or interest rate', 'Credit monitoring or identity protection',
#        'Application, originator, mortgage broker',
#        'Incorrect information on credit report', 'Repaying your loan',
#        'Delinquent account', 'Problems caused by my funds being low',
#        'Improper use of my credit report', 'Settlement process and costs',
#        'Billing disputes', 'Credit line increase/decrease',
#        'Payoff process', 'Unable to get credit report/credit score',
#        'Closing/Cancelling account',
#        "Credit reporting company's investigation",
# ...

# %%
df.Tags.unique()
# Out:
# array([nan, 'Older American', 'Servicemember',
#        'Older American, Servicemember'], dtype=object)

# %%
subset = df.loc[:,['Issue','Company']]

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
wellsDF = subset[subset.Company == 'Wells Fargo & Company']

# %%
wellsDF.describe()
# Out:
#                                            Issue                Company
# count                                      45473                  45473
# unique                                        88                      1
# top     Loan modification,collection,foreclosure  Wells Fargo & Company
# freq                                       15823                  45473

# %%
len(wellsDF['Issue'].unique())
# Out:
# 88

# %%
type(wellsDF['Issue'].unique())
# Out:
# numpy.ndarray

# %%
df.loc[:,['Date sent to company','Date received','Company response to consumer']].head(10)
# Out:
#   Date sent to company Date received     Company response to consumer
# 0            7/30/2013     7/29/2013          Closed with explanation
# 1            7/31/2013     7/29/2013          Closed with explanation
# 2            7/31/2013     7/29/2013                           Closed
# 3            7/30/2013     7/29/2013          Closed with explanation
# 4            7/30/2013     7/29/2013          Closed with explanation
# 5            7/30/2013     7/29/2013          Closed with explanation
# 6             8/7/2013     7/29/2013  Closed with non-monetary relief
# 7             8/1/2013     7/29/2013          Closed with explanation
# 8            7/30/2013     7/29/2013          Closed with explanation
# 9            7/30/2013     7/29/2013          Closed with explanation

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %% [markdown]
# Date Sent and Received seem Bogus.

# %%
df['Company response to consumer'].unique()
# Out:
# array(['Closed with explanation', 'Closed',
#        'Closed with non-monetary relief', 'Closed with monetary relief',
#        'Untimely response', 'Closed without relief', 'Closed with relief',
#        'In progress'], dtype=object)

# %%
df['Company response to consumer'].count()
# Out:
# 629106

# %%
df['Company response to consumer'].describe()
# Out:
# count                      629106
# unique                          8
# top       Closed with explanation
# freq                       461632
# Name: Company response to consumer, dtype: object

# %%
df.columns

# %%
df.loc[:,['Company','Consumer disputed?']].head(100).describe()
# Out:
#                       Company Consumer disputed?
# count                     100                 98
# unique                     40                  2
# top     Wells Fargo & Company                 No
# freq                       16                 79
